# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('pizza_sales.csv')
df.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0         1         1     hawaiian_m         1  01-01-2015   11:38:36
# 1         2         2  classic_dlx_m         1  01-01-2015   11:57:40
# 2         3         2  five_cheese_l         1  01-01-2015   11:57:40
# 3         4         2    ital_supr_l         1  01-01-2015   11:57:40
# 4         5         2     mexicana_m         1  01-01-2015   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# ...

# %%
df.isnull().sum()
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48620 non-null  str
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  str
#  5   order_time         48620 non-null  str
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  str
#  9   pizza_category     48620 non-null  str
#  10  pizza_ingredients  48620 non-null  str
#  11  pizza_name         48620 non-null  str
# dtypes: float64(2), int64(3), str(7)
# memory usage: 4.5 MB

# %%
df.describe()
# Out:
#            pizza_id      order_id      quantity    unit_price   total_price
# count  48620.000000  48620.000000  48620.000000  48620.000000  48620.000000
# mean   24310.500000  10701.479761      1.019622     16.494132     16.821474
# std    14035.529381   6180.119770      0.143077      3.621789      4.437398
# min        1.000000      1.000000      1.000000      9.750000      9.750000
# 25%    12155.750000   5337.000000      1.000000     12.750000     12.750000
# 50%    24310.500000  10682.500000      1.000000     16.500000     16.500000
# 75%    36465.250000  16100.000000      1.000000     20.250000     20.500000
# max    48620.000000  21350.000000      4.000000     35.950000     83.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Covert into date format
df['order_date']=pd.to_datetime(df['order_date'],format="%d-%m-%Y")
df['order_date'].tail(5)
# Out:
# 48615   2015-12-31
# 48616   2015-12-31
# 48617   2015-12-31
# 48618   2015-12-31
# 48619   2015-12-31
# Name: order_date, dtype: datetime64[us]

# %%
df['order_time']=pd.to_datetime(df['order_time'],format="%H:%M:%S").dt.time

# %%
#extract new column
df['day_of_week']=df['order_date'].dt.day_name()
df['day_of_week']

df['month']=df['order_date'].dt.month_name()
df['month']

df['hours_of_day']=pd.to_datetime(df['order_time'],format="%H:%M:%S").dt.hour
df['hours_of_day']
# Out:
# 0        11
# 1        11
# 2        11
# 3        11
# 4        11
#          ..
# 48615    21
# 48616    21
# 48617    21
# 48618    22
# 48619    23
# Name: hours_of_day, Length: 48620, dtype: int32

# %%
#df=df.drop('day_of_week',axis=1)
df.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0         1         1     hawaiian_m         1 2015-01-01   11:38:36
# 1         2         2  classic_dlx_m         1 2015-01-01   11:57:40
# 2         3         2  five_cheese_l         1 2015-01-01   11:57:40
# 3         4         2    ital_supr_l         1 2015-01-01   11:57:40
# 4         5         2     mexicana_m         1 2015-01-01   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# ...

# %%
df['week'] = df['order_date'].dt.to_period('W').apply(lambda r: r.start_time)

# Weekly summary report
weekly_report = df.groupby('week').agg(
    total_revenue=('total_price', 'sum'),
    total_orders=('order_id', 'nunique'),   # unique orders, not rows
    total_quantity=('quantity', 'sum'),
    avg_order_value=('total_price', 'mean')
).reset_index()

print(weekly_report)
# Out:
#          week  total_revenue  total_orders  total_quantity  avg_order_value
# 0  2014-12-29        9863.60           254             591        16.976936
# 1  2015-01-05       15999.05           427             972        16.823396
# 2  2015-01-12       15115.95           400             917        16.832906
# 3  2015-01-19       15652.80           415             968        16.442017
# 4  2015-01-26       16351.10           436             975        16.996985
# 5  2015-02-02       16175.70           422             988        16.641667
# 6  2015-02-09       16085.55           423             976        16.755781
# 7  2015-02-16       15345.90           393             933        16.789825
# 8  2015-02-23       15961.80           409             972        16.678997
# 9  2015-03-02       16564.45           420             996        17.059166
# 10 2015-03-09       15820.55           404             965        16.759057
# ...

# %%
from sqlalchemy import create_engine

username="postgres"
password="nitin123"
host="localhost"
port="5432"
database="pizza_sales_db"# database name you created in sql

engine=create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

table_name="pizza_sales"
df.to_sql(table_name,engine,if_exists="replace",index=False)
print(f"Data Successfully Loaded into table '{table_name}'in database'{database}'.")
# Out:
# Data Successfully Loaded into table 'pizza_sales'in database'pizza_sales_db'.
